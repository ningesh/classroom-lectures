# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv('selfmadedata.csv', delimiter=',',nrows=25,skiprows=[1])

# %%
df
# Out:
#     id  gender  age  exericse  dietplan  area  workinghours  isbeforeinfamily  \
# 0    2       1   40         0         3     2             1                 1
# 1    3       1   70         1         2     1             4                 1
# 2    4       0  100         2         3     2             3                 0
# 3    5       1   12         3         1     3             5                 1
# 4    6       1   14         4         2     1             7                 0
# 5    7       1   16         5         3     2             3                 0
# 6    8       0   18         1         4     4             1                 1
# 7    9       1   20         3         1     3             3                 0
# 8   10       0   22         5         2     5             4                 0
# 9   11       1   24         7         3     6             5                 1
# 10  12       1   26         2         1     7             6                 0
# ...

# %%
from matplotlib import style
plt.style.use('ggplot')

# %%
x=df['gender']
y=df['age']
z=df['weight']
a=df['height']
cancer=df['classifed']
idx_1 = np.where(df['classifed'] == 1)
idx_0 = np.where(df['classifed'] == 0)
df.iloc[idx_1]
plt.grid(True,color='k')
plt.scatter(df.iloc[idx_1].age, df.iloc[idx_1].weight, color='r',label='lung cancer')
plt.scatter(df.iloc[idx_0].age, df.iloc[idx_0].weight, color='g',label='skin cancer')
plt.xlabel('age')
plt.ylabel('weight')
plt.title('age,weight classification cancer type')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %%
plt.scatter(df.iloc[idx_1].age, df.iloc[idx_1].exericse, color='r',label='lung cancer')
plt.scatter(df.iloc[idx_0].age, df.iloc[idx_0].exericse, color='g',label='skin cancer')
plt.grid(True,color='k')
plt.title('age,exericse classification cancer type')
plt.xlabel('age')
plt.ylabel('exericse')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %%
plt.scatter(df.iloc[idx_1].age, df.iloc[idx_1].height, color='r',label='lung cancer')
plt.scatter(df.iloc[idx_0].age, df.iloc[idx_0].height, color='g',label='skin cancer')
plt.grid(True,color='k')
plt.xlabel('age')
plt.ylabel('height')
plt.title('age,height classification cancer type')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %%
plt.scatter(df.iloc[idx_1].age, df.iloc[idx_1].gender, color='r',label='lung cancer')
plt.scatter(df.iloc[idx_0].age, df.iloc[idx_0].gender, color='g',label='skin cancer')
plt.grid(True,color='k')
plt.xlabel('age')
plt.ylabel('gender')
plt.title('age,gender classification cancer type')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %% [markdown]
# x1=idx_1[0]
# y1=idx_1[0]
# x2=idx_0[0]
# y2=idx_0[0]

# %%
plt.scatter(df.iloc[idx_1].gender, df.iloc[idx_1].age, color='r',label='lung cancer')
plt.scatter(df.iloc[idx_0].gender, df.iloc[idx_0].age, color='g',label='skin cancer')
plt.grid(True,color='k')
plt.xlabel('gender')
plt.ylabel('age')
plt.title('age,gender 0-male 1-female classification cancer type')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N))

data = (df.iloc[idx_1].gender, df.iloc[idx_1].age,df.iloc[idx_1].height)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Matplot scatter plot')
plt.legend(loc=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-060764342f19> in <module>
#      17
#      18 for data, color, group in zip(data, colors, groups):
# ---> 19     x, y = data
#      20     ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
#      21
#
# ValueError: too many values to unpack (expected 2)

# %%
N = 60
g1 = (df.iloc[idx_0].age, df.iloc[idx_0].height)
g2 = (df.iloc[idx_0].age, df.iloc[idx_0].weight)
g3 = (df.iloc[idx_0].age, df.iloc[idx_0].gender)
g4 = (df.iloc[idx_0].age, df.iloc[idx_0].exericse)
g5 = (df.iloc[idx_0].age, df.iloc[idx_0].dietplan)
g6 = (df.iloc[idx_0].age, df.iloc[idx_0].area)
g7 = (df.iloc[idx_0].age, df.iloc[idx_0].workinghours)
g8 = (df.iloc[idx_0].age, df.iloc[idx_0].isbeforeinfamily)



data = (g1,g2,g3,g4,g5,g6,g7,g8)
data
colors = ("red", "green", "blue","cyan","magenta","yellow","black","white")
groups = ("height", "weight", "gender","exericse","dietplan","area","workinghours","isbeforeinfamily")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('Lung cancer')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %%
g1 = (df.iloc[idx_1].age, df.iloc[idx_1].height)
g2 = (df.iloc[idx_1].age, df.iloc[idx_1].weight)
g3 = (df.iloc[idx_1].age, df.iloc[idx_1].gender)
g4 = (df.iloc[idx_1].age, df.iloc[idx_1].exericse)
g5 = (df.iloc[idx_1].age, df.iloc[idx_1].dietplan)
g6 = (df.iloc[idx_1].age, df.iloc[idx_1].area)
g7 = (df.iloc[idx_1].age, df.iloc[idx_1].workinghours)
g8 = (df.iloc[idx_1].age, df.iloc[idx_1].isbeforeinfamily)



data = (g1,g2,g3,g4,g5,g6,g7,g8)
data
colors = ("red", "green", "blue","cyan","magenta","yellow","black","white")
groups = ("height", "weight", "gender","exericse","dietplan","area","workinghours","isbeforeinfamily")

# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

for data, color, group in zip(data, colors, groups):
    x, y = data
    ax.scatter(x, y, alpha=0.8, c=color, edgecolors='none', s=30, label=group)

plt.title('skin cancer')
plt.legend(bbox_to_anchor=(1.5, 1.05))

# %%
num = 3
if num > 0:
    print('number is greater than 3')
# Out:
# number is greater than 3

# %%
n = 15

# initialize sum and counter
sum = 0
i = 1

while i <= n:
    if i%2==1:
        sum = sum + i
    i = i+1    # update counter

# print the sum
print("The sum is", sum)
# Out:
# The sum is 64
